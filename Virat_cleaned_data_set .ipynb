# %% [markdown]
# ## Importing the Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
df=pd.read_csv(r'C:\Users\admin\Downloads\virat.csv')

# %%
df
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %%
virat=pd.DataFrame(df)

# %%
virat
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %% [markdown]
# ## Cleaning the Dataset

# %%
virat.isnull().sum()
# Out:
# Score                0
# Out/Not Out          0
# Against              0
# Batting Order        0
# Inn.                 0
# Strike Rate         27
# Venue                0
# Column1              0
# H/A                  0
# Date                 0
# Result               0
# Format               0
# Man of the Match     0
# Captain              0
# dtype: int64

# %%
virat["Strike Rate"]=virat["Strike Rate"].fillna(virat["Strike Rate"].mean())

# %%
virat
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2   114.019545
# 1     103         Out   New Zealand              5     2   114.019545
# 2     103         Out       England              5     2   114.019545
# 3     107         Out     Australia              5     2   114.019545
# 4     119         Out  South Africa              4     1   114.019545
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1    96.670000
# 67    123         Out     Australia              3     2   129.470000
# 68    120         Out   West Indies              3     1    96.000000
# 69    114     Not Out   West Indies              3     2   115.150000
# 70    122     Not Out    Afganistan              1     1   200.000000
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %%
virat.isnull().sum()
# Out:
# Score               0
# Out/Not Out         0
# Against             0
# Batting Order       0
# Inn.                0
# Strike Rate         0
# Venue               0
# Column1             0
# H/A                 0
# Date                0
# Result              0
# Format              0
# Man of the Match    0
# Captain             0
# dtype: int64

# %%
virat.rename(columns={"Column1":"City"},inplace=True)

# %%
virat
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2   114.019545
# 1     103         Out   New Zealand              5     2   114.019545
# 2     103         Out       England              5     2   114.019545
# 3     107         Out     Australia              5     2   114.019545
# 4     119         Out  South Africa              4     1   114.019545
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1    96.670000
# 67    123         Out     Australia              3     2   129.470000
# 68    120         Out   West Indies              3     1    96.000000
# 69    114     Not Out   West Indies              3     2   115.150000
# 70    122     Not Out    Afganistan              1     1   200.000000
#
#                                    Venue            City   H/A        Date  \
# ...

# %%
virat.drop(columns="Out/Not Out",inplace=True)

# %%
virat
# Out:
#     Score       Against  Batting Order  Inn.  Strike Rate  \
# 0     116     Australia              6     2   114.019545
# 1     103   New Zealand              5     2   114.019545
# 2     103       England              5     2   114.019545
# 3     107     Australia              5     2   114.019545
# 4     119  South Africa              4     1   114.019545
# ..    ...           ...            ...   ...          ...
# 66    116     Australia              3     1    96.670000
# 67    123     Australia              3     2   129.470000
# 68    120   West Indies              3     1    96.000000
# 69    114   West Indies              3     2   115.150000
# 70    122    Afganistan              1     1   200.000000
#
#                                    Venue            City   H/A        Date  \
# 0                          Adelaide Oval        Adelaide  Away  24-01-2012
# 1                 M. Chinnaswamy Stadium       Bangalore  Home  31-08-2012
# ...

# %%
virat.drop(["Captain"],axis=1,inplace=True)

# %%
virat
# Out:
#     Score       Against  Batting Order  Inn.  Strike Rate  \
# 0     116     Australia              6     2   114.019545
# 1     103   New Zealand              5     2   114.019545
# 2     103       England              5     2   114.019545
# 3     107     Australia              5     2   114.019545
# 4     119  South Africa              4     1   114.019545
# ..    ...           ...            ...   ...          ...
# 66    116     Australia              3     1    96.670000
# 67    123     Australia              3     2   129.470000
# 68    120   West Indies              3     1    96.000000
# 69    114   West Indies              3     2   115.150000
# 70    122    Afganistan              1     1   200.000000
#
#                                    Venue            City   H/A        Date  \
# 0                          Adelaide Oval        Adelaide  Away  24-01-2012
# 1                 M. Chinnaswamy Stadium       Bangalore  Home  31-08-2012
# ...

# %%
virat.rename(columns={"Inn.":"Innings"},inplace=True)

# %%
virat
# Out:
#     Score       Against  Batting Order  Innings  Strike Rate  \
# 0     116     Australia              6        2   114.019545
# 1     103   New Zealand              5        2   114.019545
# 2     103       England              5        2   114.019545
# 3     107     Australia              5        2   114.019545
# 4     119  South Africa              4        1   114.019545
# ..    ...           ...            ...      ...          ...
# 66    116     Australia              3        1    96.670000
# 67    123     Australia              3        2   129.470000
# 68    120   West Indies              3        1    96.000000
# 69    114   West Indies              3        2   115.150000
# 70    122    Afganistan              1        1   200.000000
#
#                                    Venue            City   H/A        Date  \
# 0                          Adelaide Oval        Adelaide  Away  24-01-2012
# 1                 M. Chinnaswamy Stadium       Bangalore  Home  31-08-2012
# ...
